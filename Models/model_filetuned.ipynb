# %%
from ultralytics import YOLO

DATA_YAML = "/Users/artemsaltanovskyi/Documents/2025-2026-2/2MCTE2-Advancded_AI/exam/AIProject2026/Data/Yaml/Data.yaml"
PROJECT_DIR = "/Users/artemsaltanovskyi/Documents/2025-2026-2/2MCTE2-Advancded_AI/exam/AIProject2026/Models/Results/Models"

model = YOLO("yolo11n.pt")

model.train(
    data=DATA_YAML,
    epochs=50,
    imgsz=640,
    batch=4,
    project=PROJECT_DIR,
    name="yolo11s_finetuned",
    exist_ok=True
)
# Out:
# ...
# Ultralytics 8.4.42 🚀 Python-3.11.11 torch-2.10.0 CPU (Apple M3)
# ...
